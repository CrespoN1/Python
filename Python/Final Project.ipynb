# %%
import requests
import json 
import urllib
import pandas as pd
import seaborn as sns
import numpy as np

# %%
ls ~/
# Out:
# anaconda3/  GPAKiller.csv  workspace/

# %%
df = pd.read_csv("resources/data/GPAKiller.csv", header = 0)

# %%
df.head(111)
# Out:
#                                               case  \
# 0               Harry Pratt Co. warehouse shooting
# 1                  Pennsylvania hotel bar shooting
# 2                           SunTrust bank shooting
# 3                          Mercy Hospital shooting
# 4                 Thousand Oaks nightclub shooting
# 5                  Tree of Life synagogue shooting
# 6                      Rite Aid warehouse shooting
# 7                            T&T Trucking shooting
# 8                      Fifth Third Center shooting
# 9                         Capital Gazette shooting
# 10                   Santa Fe High School shooting
# 11                           Waffle House shooting
# 12               Yountville veterans home shooting
# 13   Marjory Stoneman Douglas High School shooting
# 14                   Pennsylvania carwash shooting
# 15                    Rancho Tehama shooting spree
# 16             Texas First Baptist Church massacre
# ...

# %%
df.drop(columns=['mental_health_sources', 'sources_additional_age', 'latitude', 'longitude', 'sources', 'summary', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27'])
# Out:
#                                                case  \
# 0                Harry Pratt Co. warehouse shooting
# 1                   Pennsylvania hotel bar shooting
# 2                            SunTrust bank shooting
# 3                           Mercy Hospital shooting
# 4                  Thousand Oaks nightclub shooting
# 5                   Tree of Life synagogue shooting
# 6                       Rite Aid warehouse shooting
# 7                             T&T Trucking shooting
# 8                       Fifth Third Center shooting
# 9                          Capital Gazette shooting
# 10                    Santa Fe High School shooting
# 11                            Waffle House shooting
# 12                Yountville veterans home shooting
# 13    Marjory Stoneman Douglas High School shooting
# 14                    Pennsylvania carwash shooting
# 15                     Rancho Tehama shooting spree
# 16              Texas First Baptist Church massacre
# ...

# %%
#Question 1 
#out of all the shootings which had the most fatalities?

# %%
df.drop(columns=['mental_health_sources', 'sources_additional_age', 'latitude', 'longitude', 'sources', 'summary', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'mental_health_sources', 'Unnamed: 27'])
df.sort_values('fatalities', ascending=False).head(3)
# Out:
#                           case              location       date  \
# 19    Las Vegas Strip massacre         Las Vegas, NV    10/1/17
# 29  Orlando nightclub massacre      Orlando, Florida  6/12/2016
# 68      Virginia Tech massacre  Blacksburg, Virginia  4/16/2007
#
#                                               summary  fatalities  injured  \
# 19  Stephen Craig Paddock, 64, fired a barrage of ...        58.0    546.0
# 29  Omar Mateen, 29, attacked the Pulse nighclub i...        49.0     53.0
# 68  Virginia Tech student Seung-Hui Cho, 23, opene...        32.0     23.0
#
#     total_victims shooting location  age_of_shooter  \
# 19          604.0             Other            64.0
# 29          102.0             Other            29.0
# 68           55.0            School            23.0
#
#    prior_signs_mental_health_issues     ...      \
# 19                              TBD     ...
# 29                          Unclear     ...
# 68                              Yes     ...
#
# ...

# %%
#as we can see from this data our top three shootings occured in Las Vegas, Orlando, Blacksburg

# %%
#Question 2
#is there a correlation between the age of the shooter and the amount of people they kill?

# %%
df.plot(x='age_of_shooter', y='total_victims', style='.')

# %%
df['age_of_shooter'].corr(df['total_victims'])
# Out:
# 0.17686796641584462

# %%
#as we can see based upon the percentage, there is little to no correlation between age and the amount of people killed.
#the reason why I asked this question or thought it relavent is because based upon pyschology the younger the killer
#the more inclined they are to try new things out since they are curious, that could be seeing how many people they kill

# %%
ax = sns.regplot(df['year'], df['fatalities'], fit_reg = True)

# %%
#this is just the regression analysis that I ran to see if we could find a correlation

# %%
#Question 3
#Are the amount of mass shootings decreasing or increasing over time?

# %%
x = df['year']
y = df['fatalities']
ax = sns.regplot(x, y, order=3, fit_reg=True)

# %%
#based upon this data we can find a best fit line that fits the data. Also we can see that the amount of shootings
#are decreasing over time, within a couple outliars

# %%
newDf = df.append(pd.Series(['fake case','candy Land', '7/7/7', 'summary:King Candy killed people','10', '20', '30', 'other', '65', 'unclear', 'the board game', '0', '0', 'NA','NA', 'NA', 'NA', 'NA','NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA', 'NA'] ,index=df.columns),ignore_index=True)

# %%
newDf.head(100)
#these two lines of code are supposed to add a new row but because I ahve so much data it does not show
# Out:
#                                              case  \
# 0              Harry Pratt Co. warehouse shooting
# 1                 Pennsylvania hotel bar shooting
# 2                          SunTrust bank shooting
# 3                         Mercy Hospital shooting
# 4                Thousand Oaks nightclub shooting
# 5                 Tree of Life synagogue shooting
# 6                     Rite Aid warehouse shooting
# 7                           T&T Trucking shooting
# 8                     Fifth Third Center shooting
# 9                        Capital Gazette shooting
# 10                  Santa Fe High School shooting
# 11                          Waffle House shooting
# 12              Yountville veterans home shooting
# 13  Marjory Stoneman Douglas High School shooting
# 14                  Pennsylvania carwash shooting
# 15                   Rancho Tehama shooting spree
# 16            Texas First Baptist Church massacre
# 17            Walmart shooting in suburban Denver
# ...

# %%
#Question 1)
    #My project is mainly about gun violence in america. I have taken a data set and looked at all the mass shootings throughout the country and tried to figure if there are different correlations or trends that we can find. The data set that I have picked is an excel spreadsheet over all the mass shootings from 1982 all the way to 2019. I picked this data set from this website https://www.motherjones.com/politics/2012/12/mass-shootings-mother-jones-full-data/ .
#This website put together an excel spreadsheet of all the shootings. It is based upon a group called Mother Jones, they aim to understand the data and do intensive reporting on all the incidents to understand where things could go.  

#Question 2)
#There are 24 columns and 111 rows. Each row is a different mass shooting incident. All the columns represent a different aspect of the shooting. 

#The first column is the case-meaning the name of the incident
#Second column is the location-where the incident occured
#3rd column is the date-the day the incident occured
#4th column summary-a brief summary of how the incident occured
#5th column fatalities-the amount of people killed
#6th column injured-amount of people injured
#7th column total victims-total amount of people affected
#8th column shooting location-describes if the shooting occurred in a workplace, school, place of worship...etc   
#9th age of shooter-describes the age of the shooters
#10th and 11th mental health-describes if the shooter had any mental health problems
#12th and 13th weapons-how the shooter obtained the weapon, whether it was legally or illegally 
#14th column is the weapon type
#15th column is the race of the shooter
#16th column is the gender of the shooter
#24th column is the year the incident occured
